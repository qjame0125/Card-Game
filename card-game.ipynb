# %%
import random


class Card:
    def __init__(self, suit: str, rank_attributes: str):
        self.suit = suit
        self.rank_attributes = rank_attributes
class Deck:
    def __init__(self):
        self.card_max = 52
    def create_deck():
        deck = []
        suits = ['Heart', 'Diamond', 'Spades', 'Club']
        rank = ['King', 'Queen', 'Jack', 'Ace','2', '3', '4', '5', '6', '7', '8', '9', '10']
        
        for value in rank:
            for suit in suits:
                deck.append(value + " of " + suit)
        
        random.shuffle(deck)
        print(deck)

class Player:
    def __init__(self, player, computer):
        self.player = player
        self.computer = computer
    def _add_card(self, deck , hand):
        hand = hand.append(deck[0])
        deck.remove(deck[0])
        return hand
            
d = Deck
d.create_deck()
# Out:
# ['2 of Club', 'Ace of Spades', '7 of Heart', 'Queen of Spades', '2 of Diamond', '9 of Heart', '8 of Heart', '4 of Club', 'Jack of Heart', '6 of Spades', 'Ace of Club', '7 of Spades', '6 of Heart', '10 of Spades', '7 of Diamond', 'Ace of Diamond', '6 of Club', '4 of Heart', '2 of Heart', 'King of Heart', '5 of Spades', '3 of Spades', '9 of Diamond', '5 of Heart', 'Queen of Heart', '5 of Diamond', '10 of Club', '10 of Diamond', 'Jack of Club', '10 of Heart', '3 of Heart', '4 of Spades', '8 of Spades', 'Queen of Diamond', 'King of Diamond', 'Ace of Heart', 'Jack of Diamond', '6 of Diamond', 'Queen of Club', 'King of Club', '3 of Club', '9 of Spades', '2 of Spades', '7 of Club', '5 of Club', '9 of Club', 'King of Spades', 'Jack of Spades', '8 of Diamond', '4 of Diamond', '3 of Diamond', '8 of Club']
